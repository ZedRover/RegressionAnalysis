# %%
import numpy as np 
import pandas as pd
import seaborn as sns
from sklearn import linear_model
import matplotlib.pyplot as plt
import statsmodels.api as sm
from hw3_helper_function import *
#显示所有列
pd.set_option('display.max_columns',None)
#显示所有行
pd.set_option('display.max_rows', 50)
#设置value的显示长度为100，默认为50
pd.set_option('max_colwidth',100)
pd.set_option('max_info_columns',300)
# %matplotlib inline

# %%
df = pd.read_csv('/Users/zed/VSCode/regana/finnal-project/communities.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1994 entries, 0 to 1993
# Data columns (total 128 columns):
#  #    Column                 Non-Null Count  Dtype
# ---   ------                 --------------  -----
#  0    state                  1994 non-null   int64
#  1    county                 820 non-null    float64
#  2    community              817 non-null    float64
#  3    communityname          1994 non-null   object
#  4    fold                   1994 non-null   int64
#  5    population             1994 non-null   float64
#  6    householdsize          1994 non-null   float64
#  7    racepctblack           1994 non-null   float64
#  8    racePctWhite           1994 non-null   float64
#  9    racePctAsian           1994 non-null   float64
#  10   racePctHisp            1994 non-null   float64
#  11   agePct12t21            1994 non-null   float64
#  12   agePct12t29            1994 non-null   float64
#  13   agePct16t24            1994 non-null   float64
# ...

# %%
data = df.dropna(how = 'any')

# %%
data
# Out:
#       state  county  community     communityname  fold  population  \
# 16       36     1.0     1000.0        Albanycity     1        0.15
# 23       19   193.0    93926.0     SiouxCitycity     1        0.11
# 33       51   680.0    47672.0     Lynchburgcity     1        0.09
# 68       34    23.0    58200.0    PerthAmboycity     1        0.05
# 74        9     9.0    46520.0       Meridentown     1        0.08
# ...     ...     ...        ...               ...   ...         ...
# 1880     34    39.0    40350.0        Lindencity    10        0.04
# 1963     36    27.0    59641.0  Poughkeepsiecity    10        0.03
# 1981      9     9.0    35650.0        Hamdentown    10        0.07
# 1991      9     9.0    80070.0     Waterburytown    10        0.16
# 1992     25    17.0    72600.0       Walthamcity    10        0.08
#
#       householdsize  racepctblack  racePctWhite  racePctAsian  racePctHisp  \
# 16             0.31          0.40          0.63          0.14         0.06
# ...

# %%
X = data.iloc[:,101:126].drop(['LandArea','PopDens','PctUsePubTrans','LemasPctOfficDrugUn'],axis=1)
y = data.iloc[:,-1]

# %%
model = sm.OLS(y,sm.add_constant(X)).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     ViolentCrimesPerPop   R-squared:                       0.707
# Model:                             OLS   Adj. R-squared:                  0.646
# Method:                  Least Squares   F-statistic:                     11.59
# Date:                 Mon, 31 May 2021   Prob (F-statistic):           1.68e-18
# Time:                         20:32:15   Log-Likelihood:                 61.225
# No. Observations:                  123   AIC:                            -78.45
# Df Residuals:                      101   BIC:                            -16.58
# Df Model:                           21
# Covariance Type:             nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...
